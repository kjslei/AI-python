# %% [markdown]
# <a href="https://colab.research.google.com/github/kjslei/AI-python/blob/main/25_05_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('example_data.csv')#1번 문제
display(df)

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/mataplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
sort_df=[]
sort_df=df.sort_values('공부시간',ascending=False)
display(sort_df)
# Out:
#     학번    이름   학년   점수 분반  공부시간
# 2    3   강감찬  4.0   91  C    20
# 11  12  신사임당  2.0   96  A    20
# 8    9  신사임당  3.0   94  A     9
# 4    5   강감찬  3.0   83  C     5
# 3    4   강감찬  2.0   70  C     5
# 7    8   김유신  NaN   88  B     5
# 0    1  신사임당  NaN   69  B     4
# 15  16   이순신  4.0   75  A     4
# 1    2   홍길동  1.0   92  B     3
# 18  19   이순신  1.0  200  A     3
# 9   10   홍길동  NaN   60  B     3
# 14  15   홍길동  4.0   77  A     2
# 16  17   NaN  3.0   64  A     2
# 20  20  신사임당  2.0   61  A     2
# 19  20  신사임당  2.0   61  A     2
# 13  14   NaN  2.0   98  C     1
# 6    7   강감찬  4.0   71  C     1
# 12  13   김유신  4.0   65  A     0
# 10  11   NaN  1.0  200  C     0
# 5    6   이순신  4.0   95  A     0
# 17  18   홍길동  4.0   91  A     0

# %%
df.info()#2번 문제
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   학번      21 non-null     int64
#  1   이름      18 non-null     object
#  2   학년      18 non-null     float64
#  3   점수      21 non-null     int64
#  4   분반      21 non-null     object
#  5   공부시간    21 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.1+ KB

# %%
df.describe()#3번 문제
# Out:
#               학번         학년          점수       공부시간
# count  21.000000  18.000000   21.000000  21.000000
# mean   10.952381   2.777778   90.523810   4.333333
# std     6.127611   1.165966   38.647922   5.650959
# min     1.000000   1.000000   60.000000   0.000000
# 25%     6.000000   2.000000   69.000000   1.000000
# 50%    11.000000   3.000000   83.000000   3.000000
# 75%    16.000000   4.000000   94.000000   5.000000
# max    20.000000   4.000000  200.000000  20.000000

# %%
print(pd.isna(df).sum())# 4번 문제
# Out:
# 학번      0
# 이름      3
# 학년      3
# 점수      0
# 분반      0
# 공부시간    0
# dtype: int64

# %%
outlier=df[(df['점수']>100) | (df['공부시간']>10)]
display(outlier)
# Out:
#     학번    이름   학년   점수 분반  공부시간
# 2    3   강감찬  4.0   91  C    20
# 10  11   NaN  1.0  200  C     0
# 11  12  신사임당  2.0   96  A    20
# 18  19   이순신  1.0  200  A     3

# %%
print(f'중복 제거전 데이터프레임 크기{df.shape}')#6번 문제
df_duplicate=df[df.duplicated()]
print(f'완전 중복된 행의 갯수:{len(df_duplicate)}')
print(df_duplicate)
# Out:
# 중복 제거전 데이터프레임 크기(21, 6)
# 완전 중복된 행의 갯수:1
#     학번    이름   학년  점수 분반  공부시간
# 20  20  신사임당  2.0  61  A     2

# %%
df2 = df.drop_duplicates()#7번 문제
display(df2)
# Out:
#     학번    이름   학년   점수 분반  공부시간
# 0    1  신사임당  NaN   69  B     4
# 1    2   홍길동  1.0   92  B     3
# 2    3   강감찬  4.0   91  C    20
# 3    4   강감찬  2.0   70  C     5
# 4    5   강감찬  3.0   83  C     5
# 5    6   이순신  4.0   95  A     0
# 6    7   강감찬  4.0   71  C     1
# 7    8   김유신  NaN   88  B     5
# 8    9  신사임당  3.0   94  A     9
# 9   10   홍길동  NaN   60  B     3
# 10  11   NaN  1.0  200  C     0
# 11  12  신사임당  2.0   96  A    20
# 12  13   김유신  4.0   65  A     0
# 13  14   NaN  2.0   98  C     1
# 14  15   홍길동  4.0   77  A     2
# 15  16   이순신  4.0   75  A     4
# 16  17   NaN  3.0   64  A     2
# 17  18   홍길동  4.0   91  A     0
# 18  19   이순신  1.0  200  A     3
# 19  20  신사임당  2.0   61  A     2

# %%
import matplotlib.pyplot as plt#9번 문제
plt.scatter(df['공부시간'],df['점수'],label='원본 데이터: 공부시간vs점수')
plt.xlabel('공부시간')
plt.ylabel('점수')
plt.show()

# %%
#10번 문제
outlier_1=df[(df['점수']>100)]
print('점수 이상치: ',outlier_1)
outlier_2=df[(df['공부시간']>10)]
print(f'공부시간 이상치: |n {outlier_2}')
drop_outliers = df2.drop(index=outlier.index)
display(drop_outliers)

# %%
result = drop_outliers.groupby('분반')['점수'].mean()
print(result)#11번 문제
display(result)

# %%
df2={
    '분반':['A','B','C'],
    '점수':[77.75,77.25,80.50]
}
plt.bar(df2['분반'],df2['점수'])#12번 문제
# Out:
# <BarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt#9번 문제
plt.scatter(drop_outliers['공부시간'],drop_outliers['점수'],label='원본 데이터: 공부시간vs점수')
plt.xlabel('공부시간')
plt.ylabel('점수')
plt.show()

# %%
from abc import update_abstractmethods
Q1_score=df['점수'].quantile(0.25)
Q3_score=df['점수'].quantile(0.75)
IQR=Q3_score-Q1_score
low=Q1_score-IQR*1.5
up=Q3_score+IQR*1.5
out=df[(df['점수']<low) | (df['점수']>up)]
print(out)
df = df.drop(index=out.index)
# Out:
#     학번   이름   학년   점수 분반  공부시간
# 10  11  NaN  1.0  200  C     0
# 18  19  이순신  1.0  200  A     3

# %%
from abc import update_abstractmethods
Q1_score=df['공부시간'].quantile(0.25)
Q3_score=df['공부시간'].quantile(0.75)
IQR=Q3_score-Q1_score
low=Q1_score-IQR*1.5
up=Q3_score+IQR*1.5
out=df[(df['공부시간']<low) | (df['공부시간']>up)]
print(out)
df = df.drop(index=out.index)
# Out:
#    학번    이름   학년  점수 분반  공부시간
# 8   9  신사임당  3.0  94  A     9

# %%
plt.scatter(df['공부시간'],df['점수'],label='원본 데이터: 공부시간vs점수')
plt.xlabel('공부시간')
plt.ylabel('점수')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from font(s) DejaVu Sans.
# ...
